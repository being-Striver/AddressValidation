# %%
import pandas as pd
import sys 
import os
import numpy as np
import json

# %%
# df = pd.read_csv("C:/Users/shudh/OneDrive/Desktop/Nike/data/data.csv", sep="\t")
# df.head()
df=pd.read_csv('C:/Users/shudh/OneDrive/Desktop/Nike/data/data1.csv', sep="\t")
df.head()
# Out:
#        FailureDate EnterpriseCode  SalesOrderNo PurchaseOrderNo  \
# 0   1/17/2025 8:44     NIKEEUROPE  C01475564170    EO1609490343
# 1   1/17/2025 9:53     NIKEEUROPE  C01475571606    EO1609496835
# 2  1/17/2025 11:20     NIKEEUROPE  C01475575249    EO1609504935
# 3  1/17/2025 10:52     NIKEEUROPE  C01475575664    EO1609502460
#
#                          EDD             ErrorCode  \
# 0  2025-01-20T21:59:00+00:00      IncorrectAddress
# 1  2025-01-21T21:59:00+00:00      IncorrectAddress
# 2  2025-01-21T21:59:00+00:00  FailedCarrierRouting
# 3  2025-01-22T21:59:00+00:00      IncorrectAddress
#
#                              ErrorMsg CarrierServiceCode  \
# 0  No zones available for destination                STD
# 1  No zones available for destination                STD
# 2    There are no matching candidates                CPG
# 3  No zones available for destination                STD
#
#                        addressLine1  addressLine2        additionalName  \
# 0  SIDRA EL GAITERO. LA ESPUNCIA SN           NaN                   NaN
# 1                 1 Leinster Avenue           NaN                   NaN
# 2         160 c SPANDAUER STRAÃƒÅ¸E           NaN  NKD Deutschland GmbH
# 3                  20 Rue Belle-Vue           NaN                   NaN
#
#            city Country   zipCode  phoneNumber     contactName  Unnamed: 16  \
# 0  VILLAVICIOSA      ES     33318    628985759    MARIA CARDIN          NaN
# 1        Dublin      IE  DUBLIN 3    876812265  Cathy Steenson          NaN
# 2     FALKENSEE      DE     14612  17680664665   Dominik Sasse          NaN
# 3    Leudelange      LU    L-3345    661876244   NoÃƒÂ«l Bache          NaN
#
#    Unnamed: 17
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
